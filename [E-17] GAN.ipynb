# %% [markdown]
# # Exploration 17
# # 미니프로젝트: Segmentation map으로 도로 이미지 만들기 🚥
# |---평가문항---|---상세기준---|
# |:------|:------|
# |1. pix2pix 모델 학습을 위해 필요한 데이터셋을 적절히 구축하였다.|데이터 분석 과정 및 한 가지 이상의 augmentation을 포함한 데이터셋 구축 과정이 체계적으로 제시되었다.|
# |2. pix2pix 모델을 구현하여 성공적으로 학습 과정을 진행하였다.|U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.|
# |3. 학습 과정 및 테스트에 대한 시각화 결과를 제출하였다.|10 epoch 이상의 학습을 진행한 후 최종 테스트 결과에서 진행한 epoch 수에 걸맞은 정도의 품질을 확인하였다.|
#
# # 1. 데이터 준비

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %% [markdown]
# 👇🏻 각각이 이미지들이 어떻게 생겼는지 확인하기 위해 임의의 6장 시각화

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 이미지 크기 확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
#(256, 256, 3) 크기의 2개 이미지로 분할
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %% [markdown]
# # Augmentation
# - 학습 데이터가 1000개 뿐이라 데이터의 다양성을 높이기 위해 augmentation 방법 적용

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %% [markdown]
# 👇🏻 augmentation이 잘 되었는지 임의로 하나를 뽑아 확인

# %%
from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# # 2. Generator 구성

# %%
# Encoder
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu= layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

# %%
# Decoder   
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
# U-Net Generator
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# # 3. Discriminator 구성

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
# 각 출력의 크기 확인
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# 👇🏻 임의의 (256, 256, 3) 크기의 입력을 넣어 나오는 출력결과 시각화

# %%
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# # 4. 모델 학습

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 100 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[100]
# Generator_loss:1.6537
# L1_loss:0.2250
# Discriminator_loss:0.7359
#
# EPOCH[1] - STEP[200]
# Generator_loss:1.7302
# L1_loss:0.2486
# Discriminator_loss:0.4721
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.6920
# L1_loss:0.2264
# Discriminator_loss:1.0733
#
# EPOCH[2] - STEP[200]
# Generator_loss:2.5904
# L1_loss:0.2422
# Discriminator_loss:0.8603
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.8269
# L1_loss:0.1898
# Discriminator_loss:0.5373
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.2452
# L1_loss:0.2581
# Discriminator_loss:0.3124
#
# EPOCH[4] - STEP[100]
# Generator_loss:2.0914
# L1_loss:0.2351
# Discriminator_loss:0.4328
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.6497
# L1_loss:0.1762
# Discriminator_loss:0.9241
#
# EPOCH[5] - STEP[100]
# Generator_loss:2.0485
# L1_loss:0.2121
# Discriminator_loss:0.6256
#
# EPOCH[5] - STEP[200]
# Generator_loss:2.3217
# L1_loss:0.2053
# Discriminator_loss:0.3001
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.0710
# L1_loss:0.2313
# Discriminator_loss:0.5751
#
# EPOCH[6] - STEP[200]
# Generator_loss:2.7387
# L1_loss:0.1968
# Discriminator_loss:0.3364
#
# EPOCH[7] - STEP[100]
# Generator_loss:2.3722
# L1_loss:0.1959
# Discriminator_loss:0.5329
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.1232
# L1_loss:0.1949
# Discriminator_loss:0.5620
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.6786
# L1_loss:0.2161
# Discriminator_loss:0.1747
#
# EPOCH[8] - STEP[200]
# Generator_loss:2.7371
# L1_loss:0.1918
# Discriminator_loss:0.7822
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.0343
# L1_loss:0.1926
# Discriminator_loss:0.6522
#
# EPOCH[9] - STEP[200]
# Generator_loss:1.1079
# L1_loss:0.1715
# Discriminator_loss:1.1352
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.2769
# L1_loss:0.1786
# Discriminator_loss:0.6024
#
# EPOCH[10] - STEP[200]
# Generator_loss:2.7538
# L1_loss:0.2189
# Discriminator_loss:0.4818
#
# EPOCH[11] - STEP[100]
# Generator_loss:2.6874
# L1_loss:0.1893
# Discriminator_loss:0.4069
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.1313
# L1_loss:0.1660
# Discriminator_loss:0.8574
#
# EPOCH[12] - STEP[100]
# Generator_loss:2.2848
# L1_loss:0.1823
# Discriminator_loss:0.3727
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.6161
# L1_loss:0.1725
# Discriminator_loss:0.9789
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.5404
# L1_loss:0.1604
# Discriminator_loss:1.5910
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.2179
# L1_loss:0.1614
# Discriminator_loss:0.6079
#
# EPOCH[14] - STEP[100]
# Generator_loss:0.9379
# L1_loss:0.1631
# Discriminator_loss:0.8100
#
# EPOCH[14] - STEP[200]
# Generator_loss:2.0955
# L1_loss:0.1684
# Discriminator_loss:0.3316
#
# EPOCH[15] - STEP[100]
# Generator_loss:1.1694
# L1_loss:0.1732
# Discriminator_loss:0.6881
#
# EPOCH[15] - STEP[200]
# Generator_loss:2.0116
# L1_loss:0.1724
# Discriminator_loss:0.2580
#
# EPOCH[16] - STEP[100]
# Generator_loss:1.0509
# L1_loss:0.1888
# Discriminator_loss:0.6747
#
# EPOCH[16] - STEP[200]
# Generator_loss:0.9364
# L1_loss:0.2110
# Discriminator_loss:0.7300
#
# EPOCH[17] - STEP[100]
# Generator_loss:1.4221
# L1_loss:0.1686
# Discriminator_loss:0.4912
#
# EPOCH[17] - STEP[200]
# Generator_loss:2.1469
# L1_loss:0.1574
# Discriminator_loss:1.0855
#
# EPOCH[18] - STEP[100]
# Generator_loss:1.1244
# L1_loss:0.2155
# Discriminator_loss:0.5240
#
# EPOCH[18] - STEP[200]
# Generator_loss:2.9519
# L1_loss:0.1677
# Discriminator_loss:0.4609
#
# EPOCH[19] - STEP[100]
# Generator_loss:1.2033
# L1_loss:0.2195
# Discriminator_loss:0.7011
#
# EPOCH[19] - STEP[200]
# Generator_loss:2.1279
# L1_loss:0.1425
# Discriminator_loss:0.3721
#
# EPOCH[20] - STEP[100]
# Generator_loss:0.9938
# L1_loss:0.1673
# Discriminator_loss:0.6727
#
# EPOCH[20] - STEP[200]
# Generator_loss:2.4192
# L1_loss:0.1643
# Discriminator_loss:0.5296
#
# EPOCH[21] - STEP[100]
# Generator_loss:1.2459
# L1_loss:0.1672
# Discriminator_loss:0.5452
#
# EPOCH[21] - STEP[200]
# Generator_loss:3.6381
# L1_loss:0.1930
# Discriminator_loss:0.3467
#
# EPOCH[22] - STEP[100]
# Generator_loss:2.6578
# L1_loss:0.1666
# Discriminator_loss:0.8400
#
# EPOCH[22] - STEP[200]
# Generator_loss:2.6937
# L1_loss:0.1824
# Discriminator_loss:0.1516
#
# EPOCH[23] - STEP[100]
# Generator_loss:1.1427
# L1_loss:0.2209
# Discriminator_loss:0.5241
#
# EPOCH[23] - STEP[200]
# Generator_loss:2.5361
# L1_loss:0.1643
# Discriminator_loss:0.9978
#
# EPOCH[24] - STEP[100]
# Generator_loss:0.9246
# L1_loss:0.1677
# Discriminator_loss:0.7795
#
# EPOCH[24] - STEP[200]
# Generator_loss:3.5871
# L1_loss:0.1225
# Discriminator_loss:1.7523
#
# EPOCH[25] - STEP[100]
# Generator_loss:2.7919
# L1_loss:0.1946
# Discriminator_loss:0.1518
#
# EPOCH[25] - STEP[200]
# Generator_loss:2.1455
# L1_loss:0.1395
# Discriminator_loss:1.1907
#
# EPOCH[26] - STEP[100]
# Generator_loss:2.8524
# L1_loss:0.2098
# Discriminator_loss:0.2617
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.5210
# L1_loss:0.1662
# Discriminator_loss:0.3393
#
# EPOCH[27] - STEP[100]
# Generator_loss:1.7892
# L1_loss:0.1903
# Discriminator_loss:0.3440
#
# EPOCH[27] - STEP[200]
# Generator_loss:3.0502
# L1_loss:0.2070
# Discriminator_loss:0.0928
#
# EPOCH[28] - STEP[100]
# Generator_loss:2.3033
# L1_loss:0.1301
# Discriminator_loss:0.7090
#
# EPOCH[28] - STEP[200]
# Generator_loss:2.6461
# L1_loss:0.1799
# Discriminator_loss:0.6654
#
# EPOCH[29] - STEP[100]
# Generator_loss:0.5715
# L1_loss:0.1468
# Discriminator_loss:1.1659
#
# EPOCH[29] - STEP[200]
# Generator_loss:2.0412
# L1_loss:0.1407
# Discriminator_loss:0.4756
#
# EPOCH[30] - STEP[100]
# Generator_loss:1.1411
# L1_loss:0.1931
# Discriminator_loss:0.6785
#
# EPOCH[30] - STEP[200]
# Generator_loss:1.8559
# L1_loss:0.1526
# Discriminator_loss:0.8698
#
# EPOCH[31] - STEP[100]
# Generator_loss:2.4852
# L1_loss:0.1460
# Discriminator_loss:0.3605
#
# EPOCH[31] - STEP[200]
# Generator_loss:1.0692
# L1_loss:0.1517
# Discriminator_loss:0.8769
#
# EPOCH[32] - STEP[100]
# Generator_loss:1.0982
# L1_loss:0.1476
# Discriminator_loss:0.6375
#
# EPOCH[32] - STEP[200]
# Generator_loss:2.4797
# L1_loss:0.1442
# Discriminator_loss:0.9533
#
# EPOCH[33] - STEP[100]
# Generator_loss:3.5116
# L1_loss:0.1388
# Discriminator_loss:0.6223
#
# EPOCH[33] - STEP[200]
# Generator_loss:3.0542
# L1_loss:0.1526
# Discriminator_loss:0.1467
#
# EPOCH[34] - STEP[100]
# Generator_loss:0.2202
# L1_loss:0.1548
# Discriminator_loss:2.0538
#
# EPOCH[34] - STEP[200]
# Generator_loss:0.9886
# L1_loss:0.2189
# Discriminator_loss:0.6983
#
# EPOCH[35] - STEP[100]
# Generator_loss:2.4217
# L1_loss:0.1447
# Discriminator_loss:0.4836
#
# EPOCH[35] - STEP[200]
# Generator_loss:3.2555
# L1_loss:0.1463
# Discriminator_loss:0.3880
#
# EPOCH[36] - STEP[100]
# Generator_loss:4.0039
# L1_loss:0.1689
# Discriminator_loss:0.3465
#
# EPOCH[36] - STEP[200]
# Generator_loss:4.8170
# L1_loss:0.1412
# Discriminator_loss:0.2313
#
# EPOCH[37] - STEP[100]
# Generator_loss:2.1632
# L1_loss:0.1835
# Discriminator_loss:0.1927
#
# EPOCH[37] - STEP[200]
# Generator_loss:2.4158
# L1_loss:0.1345
# Discriminator_loss:0.9226
#
# EPOCH[38] - STEP[100]
# Generator_loss:0.9050
# L1_loss:0.1591
# Discriminator_loss:0.8015
#
# EPOCH[38] - STEP[200]
# Generator_loss:2.8604
# L1_loss:0.1352
# Discriminator_loss:0.4536
#
# EPOCH[39] - STEP[100]
# Generator_loss:1.9153
# L1_loss:0.1949
# Discriminator_loss:0.2840
#
# EPOCH[39] - STEP[200]
# Generator_loss:2.9019
# L1_loss:0.1397
# Discriminator_loss:0.2093
#
# EPOCH[40] - STEP[100]
# Generator_loss:5.1931
# L1_loss:0.1966
# Discriminator_loss:0.0778
#
# EPOCH[40] - STEP[200]
# Generator_loss:2.3105
# L1_loss:0.1377
# Discriminator_loss:0.5414
#
# EPOCH[41] - STEP[100]
# Generator_loss:4.3040
# L1_loss:0.1643
# Discriminator_loss:0.1083
#
# EPOCH[41] - STEP[200]
# Generator_loss:4.6590
# L1_loss:0.1451
# Discriminator_loss:0.5852
#
# EPOCH[42] - STEP[100]
# Generator_loss:0.8693
# L1_loss:0.1539
# Discriminator_loss:0.7437
#
# EPOCH[42] - STEP[200]
# Generator_loss:2.2110
# L1_loss:0.1569
# Discriminator_loss:0.3045
#
# EPOCH[43] - STEP[100]
# Generator_loss:2.1407
# L1_loss:0.1274
# Discriminator_loss:0.2869
#
# EPOCH[43] - STEP[200]
# Generator_loss:2.5606
# L1_loss:0.1499
# Discriminator_loss:0.2332
#
# EPOCH[44] - STEP[100]
# Generator_loss:2.7722
# L1_loss:0.1735
# Discriminator_loss:0.3323
#
# EPOCH[44] - STEP[200]
# Generator_loss:4.2000
# L1_loss:0.1409
# Discriminator_loss:0.4352
#
# EPOCH[45] - STEP[100]
# Generator_loss:2.3896
# L1_loss:0.1451
# Discriminator_loss:0.3884
#
# EPOCH[45] - STEP[200]
# Generator_loss:2.8463
# L1_loss:0.1538
# Discriminator_loss:0.1502
#
# EPOCH[46] - STEP[100]
# Generator_loss:4.1980
# L1_loss:0.1293
# Discriminator_loss:0.8402
#
# EPOCH[46] - STEP[200]
# Generator_loss:1.1990
# L1_loss:0.1909
# Discriminator_loss:0.5974
#
# EPOCH[47] - STEP[100]
# Generator_loss:3.2035
# L1_loss:0.1381
# Discriminator_loss:0.1851
#
# EPOCH[47] - STEP[200]
# Generator_loss:2.2682
# L1_loss:0.1306
# Discriminator_loss:0.6001
#
# EPOCH[48] - STEP[100]
# Generator_loss:0.7737
# L1_loss:0.1657
# Discriminator_loss:0.9633
#
# EPOCH[48] - STEP[200]
# Generator_loss:4.5669
# L1_loss:0.1267
# Discriminator_loss:0.5822
#
# EPOCH[49] - STEP[100]
# Generator_loss:3.4805
# L1_loss:0.1403
# Discriminator_loss:0.1593
#
# EPOCH[49] - STEP[200]
# Generator_loss:2.6090
# L1_loss:0.1556
# Discriminator_loss:0.1617
#
# EPOCH[50] - STEP[100]
# Generator_loss:2.3810
# L1_loss:0.1379
# Discriminator_loss:0.2487
#
# EPOCH[50] - STEP[200]
# Generator_loss:1.0582
# L1_loss:0.1294
# Discriminator_loss:0.9739
#
# EPOCH[51] - STEP[100]
# Generator_loss:1.6230
# L1_loss:0.1288
# Discriminator_loss:0.4921
#
# EPOCH[51] - STEP[200]
# Generator_loss:3.8882
# L1_loss:0.1164
# Discriminator_loss:1.2488
#
# EPOCH[52] - STEP[100]
# Generator_loss:3.8535
# L1_loss:0.1803
# Discriminator_loss:0.1672
#
# EPOCH[52] - STEP[200]
# Generator_loss:0.5002
# L1_loss:0.1120
# Discriminator_loss:1.2914
#
# EPOCH[53] - STEP[100]
# Generator_loss:3.0255
# L1_loss:0.1262
# Discriminator_loss:0.2471
#
# EPOCH[53] - STEP[200]
# Generator_loss:1.8720
# L1_loss:0.1365
# Discriminator_loss:0.2772
#
# EPOCH[54] - STEP[100]
# Generator_loss:3.4570
# L1_loss:0.1357
# Discriminator_loss:0.2252
#
# EPOCH[54] - STEP[200]
# Generator_loss:3.6020
# L1_loss:0.1948
# Discriminator_loss:0.0981
#
# EPOCH[55] - STEP[100]
# Generator_loss:2.0722
# L1_loss:0.1347
# Discriminator_loss:0.5206
#
# EPOCH[55] - STEP[200]
# Generator_loss:2.1892
# L1_loss:0.1353
# Discriminator_loss:0.2259
#
# EPOCH[56] - STEP[100]
# Generator_loss:1.0326
# L1_loss:0.1287
# Discriminator_loss:0.7361
#
# EPOCH[56] - STEP[200]
# Generator_loss:2.8422
# L1_loss:0.1380
# Discriminator_loss:0.1976
#
# EPOCH[57] - STEP[100]
# Generator_loss:4.3849
# L1_loss:0.1276
# Discriminator_loss:0.2649
#
# EPOCH[57] - STEP[200]
# Generator_loss:2.9153
# L1_loss:0.1606
# Discriminator_loss:0.1681
#
# EPOCH[58] - STEP[100]
# Generator_loss:1.7086
# L1_loss:0.1297
# Discriminator_loss:0.7687
#
# EPOCH[58] - STEP[200]
# Generator_loss:3.1362
# L1_loss:0.1393
# Discriminator_loss:0.2180
#
# EPOCH[59] - STEP[100]
# Generator_loss:3.1030
# L1_loss:0.1093
# Discriminator_loss:0.2832
#
# EPOCH[59] - STEP[200]
# Generator_loss:4.4428
# L1_loss:0.1181
# Discriminator_loss:0.7540
#
# EPOCH[60] - STEP[100]
# Generator_loss:2.5201
# L1_loss:0.1285
# Discriminator_loss:0.6422
#
# EPOCH[60] - STEP[200]
# Generator_loss:1.9149
# L1_loss:0.1355
# Discriminator_loss:0.2911
#
# EPOCH[61] - STEP[100]
# Generator_loss:0.9046
# L1_loss:0.1325
# Discriminator_loss:1.0948
#
# EPOCH[61] - STEP[200]
# Generator_loss:3.1073
# L1_loss:0.1739
# Discriminator_loss:0.3214
#
# EPOCH[62] - STEP[100]
# Generator_loss:0.8213
# L1_loss:0.1185
# Discriminator_loss:0.8548
#
# EPOCH[62] - STEP[200]
# Generator_loss:6.3688
# L1_loss:0.1393
# Discriminator_loss:1.7342
#
# EPOCH[63] - STEP[100]
# Generator_loss:1.4812
# L1_loss:0.1539
# Discriminator_loss:0.4593
#
# EPOCH[63] - STEP[200]
# Generator_loss:2.3479
# L1_loss:0.1413
# Discriminator_loss:0.1922
#
# EPOCH[64] - STEP[100]
# Generator_loss:3.3329
# L1_loss:0.1780
# Discriminator_loss:0.1591
#
# EPOCH[64] - STEP[200]
# Generator_loss:1.0739
# L1_loss:0.1114
# Discriminator_loss:0.7054
#
# EPOCH[65] - STEP[100]
# Generator_loss:1.9430
# L1_loss:0.1290
# Discriminator_loss:0.3721
#
# EPOCH[65] - STEP[200]
# Generator_loss:1.2948
# L1_loss:0.1146
# Discriminator_loss:0.6484
#
# EPOCH[66] - STEP[100]
# Generator_loss:3.0019
# L1_loss:0.1390
# Discriminator_loss:0.6479
#
# EPOCH[66] - STEP[200]
# Generator_loss:2.3259
# L1_loss:0.1273
# Discriminator_loss:0.2772
#
# EPOCH[67] - STEP[100]
# Generator_loss:2.8855
# L1_loss:0.1340
# Discriminator_loss:0.2935
#
# EPOCH[67] - STEP[200]
# Generator_loss:3.6963
# L1_loss:0.2248
# Discriminator_loss:0.0490
#
# EPOCH[68] - STEP[100]
# Generator_loss:1.2383
# L1_loss:0.2036
# Discriminator_loss:0.5717
#
# EPOCH[68] - STEP[200]
# Generator_loss:1.6596
# L1_loss:0.1369
# Discriminator_loss:0.4251
#
# EPOCH[69] - STEP[100]
# Generator_loss:3.3959
# L1_loss:0.1237
# Discriminator_loss:0.3556
#
# EPOCH[69] - STEP[200]
# Generator_loss:5.6706
# L1_loss:0.1568
# Discriminator_loss:0.1250
#
# EPOCH[70] - STEP[100]
# Generator_loss:2.3879
# L1_loss:0.1066
# Discriminator_loss:0.3444
#
# EPOCH[70] - STEP[200]
# Generator_loss:0.5708
# L1_loss:0.1345
# Discriminator_loss:1.4980
#
# EPOCH[71] - STEP[100]
# Generator_loss:2.8411
# L1_loss:0.1702
# Discriminator_loss:0.2770
#
# EPOCH[71] - STEP[200]
# Generator_loss:3.2780
# L1_loss:0.1240
# Discriminator_loss:0.4481
#
# EPOCH[72] - STEP[100]
# Generator_loss:3.5018
# L1_loss:0.1262
# Discriminator_loss:0.2094
#
# EPOCH[72] - STEP[200]
# Generator_loss:5.0131
# L1_loss:0.1015
# Discriminator_loss:2.5361
#
# EPOCH[73] - STEP[100]
# Generator_loss:4.1790
# L1_loss:0.1820
# Discriminator_loss:0.0504
#
# EPOCH[73] - STEP[200]
# Generator_loss:4.1505
# L1_loss:0.1372
# Discriminator_loss:0.2193
#
# EPOCH[74] - STEP[100]
# Generator_loss:3.4977
# L1_loss:0.1084
# Discriminator_loss:0.3575
#
# EPOCH[74] - STEP[200]
# Generator_loss:2.0996
# L1_loss:0.1148
# Discriminator_loss:0.3709
#
# EPOCH[75] - STEP[100]
# Generator_loss:1.9237
# L1_loss:0.1088
# Discriminator_loss:2.2314
#
# EPOCH[75] - STEP[200]
# Generator_loss:2.6527
# L1_loss:0.1225
# Discriminator_loss:0.2847
#
# EPOCH[76] - STEP[100]
# Generator_loss:5.2572
# L1_loss:0.1571
# Discriminator_loss:0.1816
#
# EPOCH[76] - STEP[200]
# Generator_loss:3.3757
# L1_loss:0.1296
# Discriminator_loss:0.5709
#
# EPOCH[77] - STEP[100]
# Generator_loss:3.1650
# L1_loss:0.1220
# Discriminator_loss:0.6801
#
# EPOCH[77] - STEP[200]
# Generator_loss:0.7131
# L1_loss:0.1849
# Discriminator_loss:1.1487
#
# EPOCH[78] - STEP[100]
# Generator_loss:0.5938
# L1_loss:0.1201
# Discriminator_loss:1.3343
#
# EPOCH[78] - STEP[200]
# Generator_loss:6.0204
# L1_loss:0.1475
# Discriminator_loss:0.0538
#
# EPOCH[79] - STEP[100]
# Generator_loss:1.2585
# L1_loss:0.1371
# Discriminator_loss:0.6164
#
# EPOCH[79] - STEP[200]
# Generator_loss:3.2396
# L1_loss:0.1108
# Discriminator_loss:0.1232
#
# EPOCH[80] - STEP[100]
# Generator_loss:2.6584
# L1_loss:0.1148
# Discriminator_loss:0.3686
#
# EPOCH[80] - STEP[200]
# Generator_loss:3.7381
# L1_loss:0.1352
# Discriminator_loss:0.0767
#
# EPOCH[81] - STEP[100]
# Generator_loss:0.3929
# L1_loss:0.1539
# Discriminator_loss:1.5521
#
# EPOCH[81] - STEP[200]
# Generator_loss:1.8972
# L1_loss:0.1265
# Discriminator_loss:0.2830
#
# EPOCH[82] - STEP[100]
# Generator_loss:1.9592
# L1_loss:0.1434
# Discriminator_loss:0.3244
#
# EPOCH[82] - STEP[200]
# Generator_loss:5.4528
# L1_loss:0.1500
# Discriminator_loss:0.9482
#
# EPOCH[83] - STEP[100]
# Generator_loss:3.1660
# L1_loss:0.1364
# Discriminator_loss:0.2017
#
# EPOCH[83] - STEP[200]
# Generator_loss:2.4536
# L1_loss:0.1464
# Discriminator_loss:0.1557
#
# EPOCH[84] - STEP[100]
# Generator_loss:2.4938
# L1_loss:0.1258
# Discriminator_loss:0.2631
#
# EPOCH[84] - STEP[200]
# Generator_loss:3.3088
# L1_loss:0.1238
# Discriminator_loss:0.1750
#
# EPOCH[85] - STEP[100]
# Generator_loss:3.6121
# L1_loss:0.1606
# Discriminator_loss:0.6771
#
# EPOCH[85] - STEP[200]
# Generator_loss:3.9034
# L1_loss:0.1147
# Discriminator_loss:0.2809
#
# EPOCH[86] - STEP[100]
# Generator_loss:0.7186
# L1_loss:0.1261
# Discriminator_loss:1.1607
#
# EPOCH[86] - STEP[200]
# Generator_loss:4.4247
# L1_loss:0.1300
# Discriminator_loss:0.5346
#
# EPOCH[87] - STEP[100]
# Generator_loss:4.4031
# L1_loss:0.1195
# Discriminator_loss:0.1437
#
# EPOCH[87] - STEP[200]
# Generator_loss:4.3854
# L1_loss:0.1029
# Discriminator_loss:0.5376
#
# EPOCH[88] - STEP[100]
# Generator_loss:5.6808
# L1_loss:0.1324
# Discriminator_loss:0.2405
#
# EPOCH[88] - STEP[200]
# Generator_loss:5.9738
# L1_loss:0.1355
# Discriminator_loss:0.8693
#
# EPOCH[89] - STEP[100]
# Generator_loss:7.9908
# L1_loss:0.2182
# Discriminator_loss:0.5013
#
# EPOCH[89] - STEP[200]
# Generator_loss:3.4442
# L1_loss:0.1429
# Discriminator_loss:0.1370
#
# EPOCH[90] - STEP[100]
# Generator_loss:3.6717
# L1_loss:0.0972
# Discriminator_loss:0.6040
#
# EPOCH[90] - STEP[200]
# Generator_loss:2.5415
# L1_loss:0.1146
# Discriminator_loss:0.2360
#
# EPOCH[91] - STEP[100]
# Generator_loss:7.3391
# L1_loss:0.1614
# Discriminator_loss:0.1371
#
# EPOCH[91] - STEP[200]
# Generator_loss:2.3239
# L1_loss:0.1006
# Discriminator_loss:0.5867
#
# EPOCH[92] - STEP[100]
# Generator_loss:3.2844
# L1_loss:0.1355
# Discriminator_loss:0.6449
#
# EPOCH[92] - STEP[200]
# Generator_loss:2.4832
# L1_loss:0.1416
# Discriminator_loss:0.2166
#
# EPOCH[93] - STEP[100]
# Generator_loss:2.4352
# L1_loss:0.1239
# Discriminator_loss:0.2189
#
# EPOCH[93] - STEP[200]
# Generator_loss:3.3856
# L1_loss:0.1197
# Discriminator_loss:0.1348
#
# EPOCH[94] - STEP[100]
# Generator_loss:7.6805
# L1_loss:0.1299
# Discriminator_loss:0.0461
#
# EPOCH[94] - STEP[200]
# Generator_loss:5.0138
# L1_loss:0.1642
# Discriminator_loss:0.7828
#
# EPOCH[95] - STEP[100]
# Generator_loss:1.0377
# L1_loss:0.1093
# Discriminator_loss:0.8468
#
# EPOCH[95] - STEP[200]
# Generator_loss:5.2073
# L1_loss:0.1616
# Discriminator_loss:0.0752
#
# EPOCH[96] - STEP[100]
# Generator_loss:0.3779
# L1_loss:0.1563
# Discriminator_loss:1.7618
#
# EPOCH[96] - STEP[200]
# Generator_loss:0.9013
# L1_loss:0.1277
# Discriminator_loss:0.7483
#
# EPOCH[97] - STEP[100]
# Generator_loss:5.4570
# L1_loss:0.1562
# Discriminator_loss:0.0660
#
# EPOCH[97] - STEP[200]
# Generator_loss:3.9163
# L1_loss:0.1488
# Discriminator_loss:0.2021
#
# EPOCH[98] - STEP[100]
# Generator_loss:5.4185
# L1_loss:0.1357
# Discriminator_loss:0.2891
#
# EPOCH[98] - STEP[200]
# Generator_loss:4.7285
# L1_loss:0.1389
# Discriminator_loss:0.0459
#
# EPOCH[99] - STEP[100]
# Generator_loss:4.0026
# L1_loss:0.1297
# Discriminator_loss:0.4174
#
# EPOCH[99] - STEP[200]
# Generator_loss:6.0281
# L1_loss:0.1313
# Discriminator_loss:0.0388
#
# EPOCH[100] - STEP[100]
# Generator_loss:3.4274
# L1_loss:0.1201
# Discriminator_loss:0.1180
#
# EPOCH[100] - STEP[200]
# Generator_loss:6.0624
# L1_loss:0.1405
# Discriminator_loss:0.0619

# %% [markdown]
# # 5. 모델 테스트

# %%
test_ind = 2
val_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'

f = data_path + os.listdir(val_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# # 회고
# - 이번 노드는 이미지의 학습 과정을 볼 수 있어서 좋았다.
# - Epoch의 수를 늘리면 성능이 더 좋아질까 했는데 시간이 생각보다 많이 걸려서 여러가지 시도는 하지 못했다.
# - 근데 하면서 드는 생각이 '과연 Epoch을 늘린다고 해서 정말 성능이 좋아질까?'라는 생각이 들었다.(다음에 한번 도전!)
# - 그래도 이번 노드를 통해서 CGAN을 학습해 볼 수 있어서 좋았다.
